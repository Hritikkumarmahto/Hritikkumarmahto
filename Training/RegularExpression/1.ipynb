# %% [markdown]
# ## Regex - A pattern Language for matching text
#
#    - Layer1 - Literal Matching
#    - Layer2 - Basic metacharecters
#    - Layer3 - Character classes
#    - Layer4 - Quantifiers with precision
#    - Layer5 - Group and capturing
#    - Layer6 - Core Functions

# %%
import re

# %% [markdown]
# Layer 1 - Literal maching

# %%
text="this is not a bad this is a negative review"
patter=""
